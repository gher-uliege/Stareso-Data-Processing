# %% [markdown]
# Connect to [RACE](http://www.gitan.ulg.ac.be/cms/index.php?page=donnees-de-stareso#1.) database (*Rapid Assessment of the marine Coastal Environment*) and perform a simple data query.<br>
# We will use the [psycopg2](https://wiki.postgresql.org/wiki/Psycopg2) package.

# %%
import psycopg2
import logging
import getpass
import sys
import matplotlib.pyplot as plt

# %% [markdown]
# # Prerequisites
#
# 1. You need to have a user name and password to access the database.
# 2. If you're not using the ULg network (wired or wireless), it is necessary to use the ULg Virtual Private Network (VPN), otherwise the connection won't be authorised.
#
# # Configuration
#
# ## Logging

# %%
logger = logging.getLogger()
logger.setLevel(logging.DEBUG)

# %% [markdown]
# ## Define the query
#
# If you're not familiar with the querly language, use [`pgadmin`](https://www.pgadmin.org/) (graphical administration tool for [PostgreSQL](https://www.postgresql.org/)) to prepare the request using the graphical interface.<br>
# Most of the interesting data are stored in one of these tables:
# * data,
# * timeseries,
# * profiledata.
#
# In the following query, we want to obtain the *wind speed* variable acquired from April 1st 2017 on.
#
# `data.dasa_codeds` and<br>
# `timeseries.codeds`<br>
# are the *Primary Keys* (PK) that allow us to join the 2 tables `data` and `timeseries`.

# %%
windquery = """SELECT
  data.datavalue,
  data.daytime,
  data.dataparam_codeparam
FROM
  public.data,
  public.timeseries
WHERE
  data.dasa_codeds = timeseries.codeds AND
  timeseries.tssta_codesta = 'INSJD' AND
  data.daytime > '2017-04-01 00:00:00' AND
  data.dataparam_codeparam = 'windspeed'
GROUP BY
  data.dataparam_codeparam,
  data.datavalue,
  data.daytime
ORDER BY
  data.daytime;
  """

# %% [markdown]
# We just need to make sure no *new lines* are present in the string:

# %%
windquery = windquery.replace('\n', ' ')

# %% [markdown]
# ## Connection setup
#
# You need to have an access to the database.
# Here you will have to write your credentials, but another solution would be to read them from a local file on your machine.

# %%
dbhost = getpass.getpass(prompt="Enter host:")
# Out:
# Enter host:········

# %%
dbuser = getpass.getpass(prompt="Enter user name:")
# Out:
# Enter user name:········

# %%
dbpa = getpass.getpass(prompt="Enter word:")
# Out:
# Enter word:········

# %%
conn = psycopg2.connect(host=dbhost, user=dbuser, password=dbpa, dbname="race_db_v2")

# %% [markdown]
# If you get an `OperationalError`, check if your VPN connection was properly set up.

# %% [markdown]
# ### Connection status

# %%
if conn.status == psycopg2.extensions.STATUS_READY:
    logging.info("Status: ready")
elif conn.status == psycopg2.extensions.STATUS_BEGIN:
    logging.info("Status: begin")
elif conn.status == psycopg2.extensions.STATUS_IN_TRANSACTION:
    logging.info("Status: in transaction")
elif conn.status == psycopg2.extensions.STATUS_PREPARED:
    logging.info("Status: prepared")
else:
    logging.error("Uncorrect status")
# Out:
# INFO:root:Status: ready

# %% [markdown]
# # Execute request
#
# Open a [cursor](https://en.wikipedia.org/wiki/Cursor_(databases) to perform database operations:

# %%
cur = conn.cursor()

# %% [markdown]
# Execute a command: this creates a new table

# %%
cur.execute(windquery)

# %% [markdown]
# ## Read the data into a variable

# %%
data = cur.fetchall()

# %% [markdown]
# Close the cursor and the connection:

# %%
cur.close()
conn.close()

# %%
data
# Out:
# [(0.1554, datetime.datetime(2017, 4, 1, 0, 4), 'windspeed'),
#  (0.3885, datetime.datetime(2017, 4, 1, 0, 24, 1), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 1, 0, 44, 2), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 1, 1, 4, 3), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 1, 1, 24, 4), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 1, 1, 44, 5), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 1, 2, 4, 6), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 1, 2, 24, 7), 'windspeed'),
#  (0.3885, datetime.datetime(2017, 4, 1, 2, 44, 8), 'windspeed'),
#  (3.1857, datetime.datetime(2017, 4, 1, 3, 4, 9), 'windspeed'),
#  (3.4188, datetime.datetime(2017, 4, 1, 3, 24, 10), 'windspeed'),
#  (3.7296, datetime.datetime(2017, 4, 1, 3, 44, 11), 'windspeed'),
#  (3.108, datetime.datetime(2017, 4, 1, 4, 4, 12), 'windspeed'),
#  (2.2533, datetime.datetime(2017, 4, 1, 4, 24, 13), 'windspeed'),
#  (0.8547, datetime.datetime(2017, 4, 1, 4, 44, 14), 'windspeed'),
#  (0.777, datetime.datetime(2017, 4, 1, 5, 4, 15), 'windspeed'),
#  (1.0878, datetime.datetime(2017, 4, 1, 5, 24, 16), 'windspeed'),
#  (1.554, datetime.datetime(2017, 4, 1, 5, 44, 17), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 1, 6, 4, 18), 'windspeed'),
#  (0.0777, datetime.datetime(2017, 4, 1, 6, 24, 19), 'windspeed'),
#  (1.3209, datetime.datetime(2017, 4, 1, 6, 44, 20), 'windspeed'),
#  (2.6418, datetime.datetime(2017, 4, 1, 7, 4, 21), 'windspeed'),
#  (2.6418, datetime.datetime(2017, 4, 1, 7, 24, 22), 'windspeed'),
#  (2.1756, datetime.datetime(2017, 4, 1, 7, 44, 23), 'windspeed'),
#  (0.2331, datetime.datetime(2017, 4, 1, 8, 4, 24), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 1, 8, 24, 25), 'windspeed'),
#  (1.0101, datetime.datetime(2017, 4, 1, 8, 44, 26), 'windspeed'),
#  (1.9425, datetime.datetime(2017, 4, 1, 9, 4, 27), 'windspeed'),
#  (1.9425, datetime.datetime(2017, 4, 1, 9, 24, 28), 'windspeed'),
#  (1.9425, datetime.datetime(2017, 4, 1, 9, 44, 29), 'windspeed'),
#  (2.331, datetime.datetime(2017, 4, 1, 10, 4, 30), 'windspeed'),
#  (2.331, datetime.datetime(2017, 4, 1, 10, 24, 31), 'windspeed'),
#  (1.3986, datetime.datetime(2017, 4, 1, 10, 44, 32), 'windspeed'),
#  (0.6216, datetime.datetime(2017, 4, 1, 11, 4, 33), 'windspeed'),
#  (0.0777, datetime.datetime(2017, 4, 1, 11, 24, 34), 'windspeed'),
#  (1.3209, datetime.datetime(2017, 4, 1, 11, 44, 35), 'windspeed'),
#  (0.5439, datetime.datetime(2017, 4, 1, 12, 4, 36), 'windspeed'),
#  (0.9324, datetime.datetime(2017, 4, 1, 12, 24, 37), 'windspeed'),
#  (0.9324, datetime.datetime(2017, 4, 1, 12, 44, 38), 'windspeed'),
#  (1.7094, datetime.datetime(2017, 4, 1, 13, 4, 39), 'windspeed'),
#  (1.7094, datetime.datetime(2017, 4, 1, 13, 24, 40), 'windspeed'),
#  (2.0202, datetime.datetime(2017, 4, 1, 13, 44, 41), 'windspeed'),
#  (2.0202, datetime.datetime(2017, 4, 1, 14, 4, 42), 'windspeed'),
#  (2.5641, datetime.datetime(2017, 4, 1, 14, 24, 43), 'windspeed'),
#  (1.9425, datetime.datetime(2017, 4, 1, 14, 44, 44), 'windspeed'),
#  (2.1756, datetime.datetime(2017, 4, 1, 15, 4, 45), 'windspeed'),
#  (2.4087, datetime.datetime(2017, 4, 1, 15, 24, 46), 'windspeed'),
#  (2.4087, datetime.datetime(2017, 4, 1, 15, 44, 47), 'windspeed'),
#  (3.0303, datetime.datetime(2017, 4, 1, 16, 4, 48), 'windspeed'),
#  (2.5641, datetime.datetime(2017, 4, 1, 16, 24, 49), 'windspeed'),
#  (2.9526, datetime.datetime(2017, 4, 1, 16, 44, 50), 'windspeed'),
#  (2.0202, datetime.datetime(2017, 4, 1, 17, 4, 51), 'windspeed'),
#  (3.2634, datetime.datetime(2017, 4, 1, 17, 24, 52), 'windspeed'),
#  (4.5843, datetime.datetime(2017, 4, 1, 17, 44, 53), 'windspeed'),
#  (3.9627, datetime.datetime(2017, 4, 1, 18, 4, 54), 'windspeed'),
#  (2.0202, datetime.datetime(2017, 4, 1, 18, 24, 55), 'windspeed'),
#  (2.331, datetime.datetime(2017, 4, 1, 18, 44, 56), 'windspeed'),
#  (4.9728, datetime.datetime(2017, 4, 1, 19, 4, 57), 'windspeed'),
#  (5.2059, datetime.datetime(2017, 4, 1, 19, 24, 58), 'windspeed'),
#  (6.216, datetime.datetime(2017, 4, 1, 19, 44, 59), 'windspeed'),
#  (8.7024, datetime.datetime(2017, 4, 1, 20, 5), 'windspeed'),
#  (9.6348, datetime.datetime(2017, 4, 1, 20, 25, 1), 'windspeed'),
#  (5.6721, datetime.datetime(2017, 4, 1, 20, 45, 2), 'windspeed'),
#  (0.6216, datetime.datetime(2017, 4, 1, 21, 5, 3), 'windspeed'),
#  (5.3613, datetime.datetime(2017, 4, 1, 21, 25, 4), 'windspeed'),
#  (6.7599, datetime.datetime(2017, 4, 1, 21, 45, 5), 'windspeed'),
#  (5.5167, datetime.datetime(2017, 4, 1, 22, 5, 6), 'windspeed'),
#  (5.8275, datetime.datetime(2017, 4, 1, 22, 25, 7), 'windspeed'),
#  (5.439, datetime.datetime(2017, 4, 1, 22, 45, 8), 'windspeed'),
#  (4.8951, datetime.datetime(2017, 4, 1, 23, 5, 9), 'windspeed'),
#  (3.9627, datetime.datetime(2017, 4, 1, 23, 25, 10), 'windspeed'),
#  (3.5742, datetime.datetime(2017, 4, 1, 23, 45, 11), 'windspeed'),
#  (6.0606, datetime.datetime(2017, 4, 2, 0, 4), 'windspeed'),
#  (8.3916, datetime.datetime(2017, 4, 2, 0, 24, 1), 'windspeed'),
#  (6.6822, datetime.datetime(2017, 4, 2, 0, 44, 2), 'windspeed'),
#  (6.1383, datetime.datetime(2017, 4, 2, 1, 4, 3), 'windspeed'),
#  (6.1383, datetime.datetime(2017, 4, 2, 1, 24, 4), 'windspeed'),
#  (4.7397, datetime.datetime(2017, 4, 2, 1, 44, 5), 'windspeed'),
#  (2.1756, datetime.datetime(2017, 4, 2, 2, 4, 6), 'windspeed'),
#  (0.1554, datetime.datetime(2017, 4, 2, 2, 24, 7), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 2, 2, 44, 8), 'windspeed'),
#  (0.0777, datetime.datetime(2017, 4, 2, 3, 4, 9), 'windspeed'),
#  (0.3108, datetime.datetime(2017, 4, 2, 3, 24, 10), 'windspeed'),
#  (0.8547, datetime.datetime(2017, 4, 2, 3, 44, 11), 'windspeed'),
#  (2.1756, datetime.datetime(2017, 4, 2, 4, 4, 12), 'windspeed'),
#  (2.0979, datetime.datetime(2017, 4, 2, 4, 24, 13), 'windspeed'),
#  (3.4188, datetime.datetime(2017, 4, 2, 4, 44, 14), 'windspeed'),
#  (3.7296, datetime.datetime(2017, 4, 2, 5, 4, 15), 'windspeed'),
#  (4.3512, datetime.datetime(2017, 4, 2, 5, 24, 16), 'windspeed'),
#  (4.7397, datetime.datetime(2017, 4, 2, 5, 44, 17), 'windspeed'),
#  (5.1282, datetime.datetime(2017, 4, 2, 6, 4, 18), 'windspeed'),
#  (3.7296, datetime.datetime(2017, 4, 2, 6, 24, 19), 'windspeed'),
#  (3.7296, datetime.datetime(2017, 4, 2, 6, 44, 20), 'windspeed'),
#  (2.2533, datetime.datetime(2017, 4, 2, 7, 4, 21), 'windspeed'),
#  (2.0979, datetime.datetime(2017, 4, 2, 7, 24, 22), 'windspeed'),
#  (1.9425, datetime.datetime(2017, 4, 2, 7, 44, 23), 'windspeed'),
#  (0.9324, datetime.datetime(2017, 4, 2, 8, 4, 24), 'windspeed'),
#  (0.0777, datetime.datetime(2017, 4, 2, 8, 24, 25), 'windspeed'),
#  (2.0979, datetime.datetime(2017, 4, 2, 8, 44, 26), 'windspeed'),
#  (3.2634, datetime.datetime(2017, 4, 2, 9, 4, 27), 'windspeed'),
#  (2.8749, datetime.datetime(2017, 4, 2, 9, 24, 28), 'windspeed'),
#  (2.7972, datetime.datetime(2017, 4, 2, 9, 44, 29), 'windspeed'),
#  (2.8749, datetime.datetime(2017, 4, 2, 10, 4, 30), 'windspeed'),
#  (2.9526, datetime.datetime(2017, 4, 2, 10, 24, 31), 'windspeed'),
#  (2.331, datetime.datetime(2017, 4, 2, 10, 44, 32), 'windspeed'),
#  (2.0202, datetime.datetime(2017, 4, 2, 11, 4, 33), 'windspeed'),
#  (1.7094, datetime.datetime(2017, 4, 2, 11, 24, 34), 'windspeed'),
#  (1.3209, datetime.datetime(2017, 4, 2, 11, 44, 35), 'windspeed'),
#  (2.2533, datetime.datetime(2017, 4, 2, 12, 4, 36), 'windspeed'),
#  (4.3512, datetime.datetime(2017, 4, 2, 12, 24, 37), 'windspeed'),
#  (4.8174, datetime.datetime(2017, 4, 2, 12, 44, 38), 'windspeed'),
#  (5.7498, datetime.datetime(2017, 4, 2, 13, 4, 39), 'windspeed'),
#  (6.0606, datetime.datetime(2017, 4, 2, 13, 24, 40), 'windspeed'),
#  (5.5167, datetime.datetime(2017, 4, 2, 13, 44, 41), 'windspeed'),
#  (4.1181, datetime.datetime(2017, 4, 2, 14, 4, 42), 'windspeed'),
#  (2.8749, datetime.datetime(2017, 4, 2, 14, 24, 43), 'windspeed'),
#  (3.108, datetime.datetime(2017, 4, 2, 14, 44, 44), 'windspeed'),
#  (3.2634, datetime.datetime(2017, 4, 2, 15, 4, 45), 'windspeed'),
#  (5.2836, datetime.datetime(2017, 4, 2, 15, 24, 46), 'windspeed'),
#  (8.547, datetime.datetime(2017, 4, 2, 15, 44, 47), 'windspeed'),
#  (9.8679, datetime.datetime(2017, 4, 2, 16, 4, 48), 'windspeed'),
#  (8.3916, datetime.datetime(2017, 4, 2, 16, 24, 49), 'windspeed'),
#  (8.0031, datetime.datetime(2017, 4, 2, 16, 44, 50), 'windspeed'),
#  (8.0808, datetime.datetime(2017, 4, 2, 17, 4, 51), 'windspeed'),
#  (7.8477, datetime.datetime(2017, 4, 2, 17, 24, 52), 'windspeed'),
#  (8.6247, datetime.datetime(2017, 4, 2, 17, 44, 53), 'windspeed'),
#  (9.4017, datetime.datetime(2017, 4, 2, 18, 4, 54), 'windspeed'),
#  (7.8477, datetime.datetime(2017, 4, 2, 18, 24, 55), 'windspeed'),
#  (6.3714, datetime.datetime(2017, 4, 2, 18, 44, 56), 'windspeed'),
#  (7.0707, datetime.datetime(2017, 4, 2, 19, 4, 57), 'windspeed'),
#  (9.7902, datetime.datetime(2017, 4, 2, 19, 24, 58), 'windspeed'),
#  (10.4118, datetime.datetime(2017, 4, 2, 19, 44, 59), 'windspeed'),
#  (9.324, datetime.datetime(2017, 4, 2, 20, 5), 'windspeed'),
#  (8.4693, datetime.datetime(2017, 4, 2, 20, 25, 1), 'windspeed'),
#  (8.2362, datetime.datetime(2017, 4, 2, 20, 45, 2), 'windspeed'),
#  (7.5369, datetime.datetime(2017, 4, 2, 21, 5, 3), 'windspeed'),
#  (8.0031, datetime.datetime(2017, 4, 2, 21, 25, 4), 'windspeed'),
#  (9.5571, datetime.datetime(2017, 4, 2, 21, 45, 5), 'windspeed'),
#  (10.6449, datetime.datetime(2017, 4, 2, 22, 5, 6), 'windspeed'),
#  (10.4118, datetime.datetime(2017, 4, 2, 22, 25, 7), 'windspeed'),
#  (9.7902, datetime.datetime(2017, 4, 2, 22, 45, 8), 'windspeed'),
#  (9.9456, datetime.datetime(2017, 4, 2, 23, 5, 9), 'windspeed'),
#  (10.1787, datetime.datetime(2017, 4, 2, 23, 25, 10), 'windspeed'),
#  (9.8679, datetime.datetime(2017, 4, 2, 23, 45, 11), 'windspeed'),
#  (9.4017, datetime.datetime(2017, 4, 3, 0, 4), 'windspeed'),
#  (8.6247, datetime.datetime(2017, 4, 3, 0, 24, 1), 'windspeed'),
#  (8.0808, datetime.datetime(2017, 4, 3, 0, 44, 2), 'windspeed'),
#  (8.0808, datetime.datetime(2017, 4, 3, 1, 4, 3), 'windspeed'),
#  (6.6822, datetime.datetime(2017, 4, 3, 1, 24, 4), 'windspeed'),
#  (7.6923, datetime.datetime(2017, 4, 3, 1, 44, 5), 'windspeed'),
#  (8.7024, datetime.datetime(2017, 4, 3, 2, 4, 6), 'windspeed'),
#  (7.0707, datetime.datetime(2017, 4, 3, 2, 24, 7), 'windspeed'),
#  (6.6045, datetime.datetime(2017, 4, 3, 2, 44, 8), 'windspeed'),
#  (6.993, datetime.datetime(2017, 4, 3, 3, 4, 9), 'windspeed'),
#  (6.2937, datetime.datetime(2017, 4, 3, 3, 24, 10), 'windspeed'),
#  (4.9728, datetime.datetime(2017, 4, 3, 3, 44, 11), 'windspeed'),
#  (6.4491, datetime.datetime(2017, 4, 3, 4, 4, 12), 'windspeed'),
#  (6.9153, datetime.datetime(2017, 4, 3, 4, 24, 13), 'windspeed'),
#  (7.0707, datetime.datetime(2017, 4, 3, 4, 44, 14), 'windspeed'),
#  (6.993, datetime.datetime(2017, 4, 3, 5, 4, 15), 'windspeed'),
#  (7.3038, datetime.datetime(2017, 4, 3, 5, 24, 16), 'windspeed'),
#  (7.5369, datetime.datetime(2017, 4, 3, 5, 44, 17), 'windspeed'),
#  (7.6146, datetime.datetime(2017, 4, 3, 6, 4, 18), 'windspeed'),
#  (7.6146, datetime.datetime(2017, 4, 3, 6, 24, 19), 'windspeed'),
#  (7.8477, datetime.datetime(2017, 4, 3, 6, 44, 20), 'windspeed'),
#  (8.2362, datetime.datetime(2017, 4, 3, 7, 4, 21), 'windspeed'),
#  (8.9355, datetime.datetime(2017, 4, 3, 7, 24, 22), 'windspeed'),
#  (9.0909, datetime.datetime(2017, 4, 3, 7, 44, 23), 'windspeed'),
#  (9.7125, datetime.datetime(2017, 4, 3, 8, 4, 24), 'windspeed'),
#  (9.7125, datetime.datetime(2017, 4, 3, 8, 24, 25), 'windspeed'),
#  (10.6449, datetime.datetime(2017, 4, 3, 8, 44, 26), 'windspeed'),
#  (10.4118, datetime.datetime(2017, 4, 3, 9, 4, 27), 'windspeed'),
#  (10.4118, datetime.datetime(2017, 4, 3, 9, 24, 28), 'windspeed'),
#  (10.8003, datetime.datetime(2017, 4, 3, 9, 44, 29), 'windspeed'),
#  (10.3341, datetime.datetime(2017, 4, 3, 10, 4, 30), 'windspeed'),
#  (9.8679, datetime.datetime(2017, 4, 3, 10, 24, 31), 'windspeed'),
#  (9.7902, datetime.datetime(2017, 4, 3, 10, 44, 32), 'windspeed'),
#  (9.7125, datetime.datetime(2017, 4, 3, 11, 4, 33), 'windspeed'),
#  (10.4895, datetime.datetime(2017, 4, 3, 11, 24, 34), 'windspeed'),
#  (10.4118, datetime.datetime(2017, 4, 3, 11, 44, 35), 'windspeed'),
#  (9.6348, datetime.datetime(2017, 4, 3, 12, 4, 36), 'windspeed'),
#  (9.324, datetime.datetime(2017, 4, 3, 12, 24, 37), 'windspeed'),
#  (8.547, datetime.datetime(2017, 4, 3, 12, 44, 38), 'windspeed'),
#  (8.1585, datetime.datetime(2017, 4, 3, 13, 4, 39), 'windspeed'),
#  (7.6146, datetime.datetime(2017, 4, 3, 13, 24, 40), 'windspeed'),
#  (7.6146, datetime.datetime(2017, 4, 3, 13, 44, 41), 'windspeed'),
#  (7.4592, datetime.datetime(2017, 4, 3, 14, 4, 42), 'windspeed'),
#  (7.77, datetime.datetime(2017, 4, 3, 14, 24, 43), 'windspeed'),
#  (7.5369, datetime.datetime(2017, 4, 3, 14, 44, 44), 'windspeed'),
#  (6.216, datetime.datetime(2017, 4, 3, 15, 4, 45), 'windspeed'),
#  (7.5369, datetime.datetime(2017, 4, 3, 15, 24, 46), 'windspeed'),
#  (6.2937, datetime.datetime(2017, 4, 3, 15, 44, 47), 'windspeed'),
#  (4.4289, datetime.datetime(2017, 4, 3, 16, 4, 48), 'windspeed'),
#  (5.2059, datetime.datetime(2017, 4, 3, 16, 24, 49), 'windspeed'),
#  (4.9728, datetime.datetime(2017, 4, 3, 16, 44, 50), 'windspeed'),
#  (5.5167, datetime.datetime(2017, 4, 3, 17, 4, 51), 'windspeed'),
#  (5.7498, datetime.datetime(2017, 4, 3, 17, 24, 52), 'windspeed'),
#  (6.4491, datetime.datetime(2017, 4, 3, 17, 44, 53), 'windspeed'),
#  (6.4491, datetime.datetime(2017, 4, 3, 18, 4, 54), 'windspeed'),
#  (4.8951, datetime.datetime(2017, 4, 3, 18, 24, 55), 'windspeed'),
#  (4.4289, datetime.datetime(2017, 4, 3, 18, 44, 56), 'windspeed'),
#  (3.885, datetime.datetime(2017, 4, 3, 19, 4, 57), 'windspeed'),
#  (2.0202, datetime.datetime(2017, 4, 3, 19, 24, 58), 'windspeed'),
#  (0.6993, datetime.datetime(2017, 4, 3, 19, 44, 59), 'windspeed'),
#  (1.4763, datetime.datetime(2017, 4, 3, 20, 5), 'windspeed'),
#  (4.5843, datetime.datetime(2017, 4, 3, 20, 25, 1), 'windspeed'),
#  (5.439, datetime.datetime(2017, 4, 3, 20, 45, 2), 'windspeed'),
#  (4.7397, datetime.datetime(2017, 4, 3, 21, 5, 3), 'windspeed'),
#  (4.1181, datetime.datetime(2017, 4, 3, 21, 25, 4), 'windspeed'),
#  (3.8073, datetime.datetime(2017, 4, 3, 21, 45, 5), 'windspeed'),
#  (3.5742, datetime.datetime(2017, 4, 3, 22, 5, 6), 'windspeed'),
#  (3.4965, datetime.datetime(2017, 4, 3, 22, 25, 7), 'windspeed'),
#  (2.9526, datetime.datetime(2017, 4, 3, 22, 45, 8), 'windspeed'),
#  (2.0979, datetime.datetime(2017, 4, 3, 23, 5, 9), 'windspeed'),
#  (1.554, datetime.datetime(2017, 4, 3, 23, 25, 10), 'windspeed'),
#  (1.6317, datetime.datetime(2017, 4, 3, 23, 45, 11), 'windspeed'),
#  (1.9425, datetime.datetime(2017, 4, 4, 0, 4), 'windspeed'),
#  (2.4087, datetime.datetime(2017, 4, 4, 0, 24, 1), 'windspeed'),
#  (1.7094, datetime.datetime(2017, 4, 4, 0, 44, 2), 'windspeed'),
#  (0.8547, datetime.datetime(2017, 4, 4, 1, 4, 3), 'windspeed'),
#  (1.6317, datetime.datetime(2017, 4, 4, 1, 24, 4), 'windspeed'),
#  (1.7871, datetime.datetime(2017, 4, 4, 1, 44, 5), 'windspeed'),
#  (1.7094, datetime.datetime(2017, 4, 4, 2, 4, 6), 'windspeed'),
#  (1.2432, datetime.datetime(2017, 4, 4, 2, 24, 7), 'windspeed'),
#  (0.8547, datetime.datetime(2017, 4, 4, 2, 44, 8), 'windspeed'),
#  (1.6317, datetime.datetime(2017, 4, 4, 3, 4, 9), 'windspeed'),
#  (1.3209, datetime.datetime(2017, 4, 4, 3, 24, 10), 'windspeed'),
#  (2.0202, datetime.datetime(2017, 4, 4, 3, 44, 11), 'windspeed'),
#  (2.331, datetime.datetime(2017, 4, 4, 4, 4, 12), 'windspeed'),
#  (2.7972, datetime.datetime(2017, 4, 4, 4, 24, 13), 'windspeed'),
#  (4.8174, datetime.datetime(2017, 4, 4, 4, 44, 14), 'windspeed'),
#  (6.3714, datetime.datetime(2017, 4, 4, 5, 4, 15), 'windspeed'),
#  (6.993, datetime.datetime(2017, 4, 4, 5, 24, 16), 'windspeed'),
#  (4.9728, datetime.datetime(2017, 4, 4, 5, 44, 17), 'windspeed'),
#  (4.3512, datetime.datetime(2017, 4, 4, 6, 4, 18), 'windspeed'),
#  (3.4188, datetime.datetime(2017, 4, 4, 6, 24, 19), 'windspeed'),
#  (4.1958, datetime.datetime(2017, 4, 4, 6, 44, 20), 'windspeed'),
#  (5.0505, datetime.datetime(2017, 4, 4, 7, 4, 21), 'windspeed'),
#  (5.2059, datetime.datetime(2017, 4, 4, 7, 24, 22), 'windspeed'),
#  (2.9526, datetime.datetime(2017, 4, 4, 7, 44, 23), 'windspeed'),
#  (0.3885, datetime.datetime(2017, 4, 4, 8, 4, 24), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 4, 8, 24, 25), 'windspeed'),
#  (0.3885, datetime.datetime(2017, 4, 4, 8, 44, 26), 'windspeed'),
#  (0.8547, datetime.datetime(2017, 4, 4, 9, 4, 27), 'windspeed'),
#  (2.4864, datetime.datetime(2017, 4, 4, 9, 24, 28), 'windspeed'),
#  (4.1958, datetime.datetime(2017, 4, 4, 9, 44, 29), 'windspeed'),
#  (5.6721, datetime.datetime(2017, 4, 4, 10, 4, 30), 'windspeed'),
#  (6.5268, datetime.datetime(2017, 4, 4, 10, 24, 31), 'windspeed'),
#  (5.8275, datetime.datetime(2017, 4, 4, 10, 44, 32), 'windspeed'),
#  (6.4491, datetime.datetime(2017, 4, 4, 11, 4, 33), 'windspeed'),
#  (6.3714, datetime.datetime(2017, 4, 4, 11, 24, 34), 'windspeed'),
#  (5.2059, datetime.datetime(2017, 4, 4, 11, 44, 35), 'windspeed'),
#  (4.9728, datetime.datetime(2017, 4, 4, 12, 4, 36), 'windspeed'),
#  (6.0606, datetime.datetime(2017, 4, 4, 12, 24, 37), 'windspeed'),
#  (6.1383, datetime.datetime(2017, 4, 4, 12, 44, 38), 'windspeed'),
#  (5.6721, datetime.datetime(2017, 4, 4, 13, 4, 39), 'windspeed'),
#  (4.9728, datetime.datetime(2017, 4, 4, 13, 24, 40), 'windspeed'),
#  (5.2836, datetime.datetime(2017, 4, 4, 13, 44, 41), 'windspeed'),
#  (5.5167, datetime.datetime(2017, 4, 4, 14, 4, 42), 'windspeed'),
#  (5.6721, datetime.datetime(2017, 4, 4, 14, 24, 43), 'windspeed'),
#  (4.9728, datetime.datetime(2017, 4, 4, 14, 44, 44), 'windspeed'),
#  (4.8951, datetime.datetime(2017, 4, 4, 15, 4, 45), 'windspeed'),
#  (3.2634, datetime.datetime(2017, 4, 4, 15, 24, 46), 'windspeed'),
#  (5.9052, datetime.datetime(2017, 4, 4, 15, 44, 47), 'windspeed'),
#  (5.5944, datetime.datetime(2017, 4, 4, 16, 4, 48), 'windspeed'),
#  (5.9052, datetime.datetime(2017, 4, 4, 16, 24, 49), 'windspeed'),
#  (6.5268, datetime.datetime(2017, 4, 4, 16, 44, 50), 'windspeed'),
#  (6.216, datetime.datetime(2017, 4, 4, 17, 4, 51), 'windspeed'),
#  (6.1383, datetime.datetime(2017, 4, 4, 17, 24, 52), 'windspeed'),
#  (6.3714, datetime.datetime(2017, 4, 4, 17, 44, 53), 'windspeed'),
#  (7.1484, datetime.datetime(2017, 4, 4, 18, 4, 54), 'windspeed'),
#  (7.0707, datetime.datetime(2017, 4, 4, 18, 24, 55), 'windspeed'),
#  (7.77, datetime.datetime(2017, 4, 4, 18, 44, 56), 'windspeed'),
#  (7.1484, datetime.datetime(2017, 4, 4, 19, 4, 57), 'windspeed'),
#  (6.6045, datetime.datetime(2017, 4, 4, 19, 24, 58), 'windspeed'),
#  (5.3613, datetime.datetime(2017, 4, 4, 19, 44, 59), 'windspeed'),
#  (3.0303, datetime.datetime(2017, 4, 4, 20, 5), 'windspeed'),
#  (0.4662, datetime.datetime(2017, 4, 4, 20, 25, 1), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 4, 20, 45, 2), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 4, 21, 5, 3), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 4, 21, 25, 4), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 4, 21, 45, 5), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 4, 22, 5, 6), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 4, 22, 25, 7), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 4, 22, 45, 8), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 4, 23, 5, 9), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 4, 23, 25, 10), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 4, 23, 45, 11), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 5, 0, 4), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 5, 0, 24, 1), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 5, 0, 44, 2), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 5, 1, 4, 3), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 5, 1, 24, 4), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 5, 1, 44, 5), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 5, 2, 4, 6), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 5, 2, 24, 7), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 5, 2, 44, 8), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 5, 3, 4, 9), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 5, 3, 24, 10), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 5, 3, 44, 11), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 5, 4, 4, 12), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 5, 4, 24, 13), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 5, 4, 44, 14), 'windspeed'),
#  (1.0878, datetime.datetime(2017, 4, 5, 5, 4, 15), 'windspeed'),
#  (2.331, datetime.datetime(2017, 4, 5, 5, 24, 16), 'windspeed'),
#  (3.108, datetime.datetime(2017, 4, 5, 5, 44, 17), 'windspeed'),
#  (2.2533, datetime.datetime(2017, 4, 5, 6, 4, 18), 'windspeed'),
#  (2.7195, datetime.datetime(2017, 4, 5, 6, 24, 19), 'windspeed'),
#  (2.6418, datetime.datetime(2017, 4, 5, 6, 44, 20), 'windspeed'),
#  (3.2634, datetime.datetime(2017, 4, 5, 7, 4, 21), 'windspeed'),
#  (3.0303, datetime.datetime(2017, 4, 5, 7, 24, 22), 'windspeed'),
#  (3.3411, datetime.datetime(2017, 4, 5, 7, 44, 23), 'windspeed'),
#  (4.1181, datetime.datetime(2017, 4, 5, 8, 4, 24), 'windspeed'),
#  (4.3512, datetime.datetime(2017, 4, 5, 8, 24, 25), 'windspeed'),
#  (4.5066, datetime.datetime(2017, 4, 5, 8, 44, 26), 'windspeed'),
#  (4.662, datetime.datetime(2017, 4, 5, 9, 4, 27), 'windspeed'),
#  (3.6519, datetime.datetime(2017, 4, 5, 9, 24, 28), 'windspeed'),
#  (2.9526, datetime.datetime(2017, 4, 5, 9, 44, 29), 'windspeed'),
#  (2.8749, datetime.datetime(2017, 4, 5, 10, 4, 30), 'windspeed'),
#  (2.7972, datetime.datetime(2017, 4, 5, 10, 24, 31), 'windspeed'),
#  (2.4864, datetime.datetime(2017, 4, 5, 10, 44, 32), 'windspeed'),
#  (2.5641, datetime.datetime(2017, 4, 5, 11, 4, 33), 'windspeed'),
#  (2.0979, datetime.datetime(2017, 4, 5, 11, 24, 34), 'windspeed'),
#  (1.6317, datetime.datetime(2017, 4, 5, 11, 44, 35), 'windspeed'),
#  (0.6993, datetime.datetime(2017, 4, 5, 12, 4, 36), 'windspeed'),
#  (0.0777, datetime.datetime(2017, 4, 5, 12, 24, 37), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 5, 12, 44, 38), 'windspeed'),
#  (0.0777, datetime.datetime(2017, 4, 5, 13, 4, 39), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 5, 13, 24, 40), 'windspeed'),
#  (0.0777, datetime.datetime(2017, 4, 5, 13, 44, 41), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 5, 14, 4, 42), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 5, 14, 24, 43), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 5, 14, 44, 44), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 5, 15, 4, 45), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 5, 15, 24, 46), 'windspeed'),
#  (0.4662, datetime.datetime(2017, 4, 5, 15, 44, 47), 'windspeed'),
#  (2.4087, datetime.datetime(2017, 4, 5, 16, 4, 48), 'windspeed'),
#  (3.4965, datetime.datetime(2017, 4, 5, 16, 24, 49), 'windspeed'),
#  (3.3411, datetime.datetime(2017, 4, 5, 16, 44, 50), 'windspeed'),
#  (2.4087, datetime.datetime(2017, 4, 5, 17, 4, 51), 'windspeed'),
#  (4.2735, datetime.datetime(2017, 4, 5, 17, 24, 52), 'windspeed'),
#  (2.4087, datetime.datetime(2017, 4, 5, 17, 44, 53), 'windspeed'),
#  (0.3885, datetime.datetime(2017, 4, 5, 18, 4, 54), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 5, 18, 24, 55), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 5, 18, 44, 56), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 5, 19, 4, 57), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 5, 19, 24, 58), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 5, 19, 44, 59), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 5, 20, 5), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 5, 20, 25, 1), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 5, 20, 45, 2), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 5, 21, 5, 3), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 5, 21, 25, 4), 'windspeed'),
#  (2.2533, datetime.datetime(2017, 4, 5, 21, 45, 5), 'windspeed'),
#  (1.7871, datetime.datetime(2017, 4, 5, 22, 5, 6), 'windspeed'),
#  (1.3986, datetime.datetime(2017, 4, 5, 22, 25, 7), 'windspeed'),
#  (1.3209, datetime.datetime(2017, 4, 5, 22, 45, 8), 'windspeed'),
#  (1.554, datetime.datetime(2017, 4, 5, 23, 5, 9), 'windspeed'),
#  (2.1756, datetime.datetime(2017, 4, 5, 23, 25, 10), 'windspeed'),
#  (1.4763, datetime.datetime(2017, 4, 5, 23, 45, 11), 'windspeed'),
#  (1.0101, datetime.datetime(2017, 4, 6, 0, 4), 'windspeed'),
#  (0.1554, datetime.datetime(2017, 4, 6, 0, 24, 1), 'windspeed'),
#  (0.3108, datetime.datetime(2017, 4, 6, 0, 44, 2), 'windspeed'),
#  (0.1554, datetime.datetime(2017, 4, 6, 1, 4, 3), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 6, 1, 24, 4), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 6, 1, 44, 5), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 6, 2, 4, 6), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 6, 2, 24, 7), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 6, 2, 44, 8), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 6, 3, 4, 9), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 6, 3, 24, 10), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 6, 3, 44, 11), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 6, 4, 4, 12), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 6, 4, 24, 13), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 6, 4, 44, 14), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 6, 5, 4, 15), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 6, 5, 24, 16), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 6, 5, 44, 17), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 6, 6, 4, 18), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 6, 6, 24, 19), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 6, 6, 44, 20), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 6, 7, 4, 21), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 6, 7, 24, 22), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 6, 7, 44, 23), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 6, 8, 4, 24), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 6, 8, 24, 25), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 6, 8, 44, 26), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 6, 9, 4, 27), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 6, 9, 24, 28), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 6, 9, 44, 29), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 6, 10, 4, 30), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 6, 10, 24, 31), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 6, 10, 44, 32), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 6, 11, 4, 33), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 6, 11, 24, 34), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 6, 11, 44, 35), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 6, 12, 4, 36), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 6, 12, 24, 37), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 6, 12, 44, 38), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 6, 13, 4, 39), 'windspeed'),
#  (0.0777, datetime.datetime(2017, 4, 6, 13, 24, 40), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 6, 13, 44, 41), 'windspeed'),
#  (0.3108, datetime.datetime(2017, 4, 6, 14, 4, 42), 'windspeed'),
#  (0.2331, datetime.datetime(2017, 4, 6, 14, 24, 43), 'windspeed'),
#  (0.5439, datetime.datetime(2017, 4, 6, 14, 44, 44), 'windspeed'),
#  (1.3986, datetime.datetime(2017, 4, 6, 15, 4, 45), 'windspeed'),
#  (1.9425, datetime.datetime(2017, 4, 6, 15, 24, 46), 'windspeed'),
#  (1.7871, datetime.datetime(2017, 4, 6, 15, 44, 47), 'windspeed'),
#  (2.4864, datetime.datetime(2017, 4, 6, 16, 4, 48), 'windspeed'),
#  (1.9425, datetime.datetime(2017, 4, 6, 16, 24, 49), 'windspeed'),
#  (1.9425, datetime.datetime(2017, 4, 6, 16, 44, 50), 'windspeed'),
#  (1.7871, datetime.datetime(2017, 4, 6, 17, 4, 51), 'windspeed'),
#  (2.4087, datetime.datetime(2017, 4, 6, 17, 24, 52), 'windspeed'),
#  (2.8749, datetime.datetime(2017, 4, 6, 17, 44, 53), 'windspeed'),
#  (3.5742, datetime.datetime(2017, 4, 6, 18, 4, 54), 'windspeed'),
#  (3.885, datetime.datetime(2017, 4, 6, 18, 24, 55), 'windspeed'),
#  (3.6519, datetime.datetime(2017, 4, 6, 18, 44, 56), 'windspeed'),
#  (3.108, datetime.datetime(2017, 4, 6, 19, 4, 57), 'windspeed'),
#  (3.1857, datetime.datetime(2017, 4, 6, 19, 24, 58), 'windspeed'),
#  (2.331, datetime.datetime(2017, 4, 6, 19, 44, 59), 'windspeed'),
#  (1.3209, datetime.datetime(2017, 4, 6, 20, 5), 'windspeed'),
#  (1.7871, datetime.datetime(2017, 4, 6, 20, 25, 1), 'windspeed'),
#  (1.0878, datetime.datetime(2017, 4, 6, 20, 45, 2), 'windspeed'),
#  (0.8547, datetime.datetime(2017, 4, 6, 21, 5, 3), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 6, 21, 25, 4), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 6, 21, 45, 5), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 6, 22, 5, 6), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 6, 22, 25, 7), 'windspeed'),
#  (0.1554, datetime.datetime(2017, 4, 6, 22, 45, 8), 'windspeed'),
#  (0.0777, datetime.datetime(2017, 4, 6, 23, 5, 9), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 6, 23, 25, 10), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 6, 23, 45, 11), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 7, 0, 4), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 7, 0, 24, 1), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 7, 0, 44, 2), 'windspeed'),
#  (0.777, datetime.datetime(2017, 4, 7, 1, 4, 3), 'windspeed'),
#  (2.0202, datetime.datetime(2017, 4, 7, 1, 24, 4), 'windspeed'),
#  (1.7871, datetime.datetime(2017, 4, 7, 1, 44, 5), 'windspeed'),
#  (2.2533, datetime.datetime(2017, 4, 7, 2, 4, 6), 'windspeed'),
#  (3.3411, datetime.datetime(2017, 4, 7, 2, 24, 7), 'windspeed'),
#  (4.5066, datetime.datetime(2017, 4, 7, 2, 44, 8), 'windspeed'),
#  (1.3986, datetime.datetime(2017, 4, 7, 3, 4, 9), 'windspeed'),
#  (2.1756, datetime.datetime(2017, 4, 7, 3, 24, 10), 'windspeed'),
#  (2.331, datetime.datetime(2017, 4, 7, 3, 44, 11), 'windspeed'),
#  (2.2533, datetime.datetime(2017, 4, 7, 4, 4, 12), 'windspeed'),
#  (2.9526, datetime.datetime(2017, 4, 7, 4, 24, 13), 'windspeed'),
#  (3.4965, datetime.datetime(2017, 4, 7, 4, 44, 14), 'windspeed'),
#  (3.4965, datetime.datetime(2017, 4, 7, 5, 4, 15), 'windspeed'),
#  (3.6519, datetime.datetime(2017, 4, 7, 5, 24, 16), 'windspeed'),
#  (2.4087, datetime.datetime(2017, 4, 7, 5, 44, 17), 'windspeed'),
#  (1.0878, datetime.datetime(2017, 4, 7, 6, 4, 18), 'windspeed'),
#  (0.2331, datetime.datetime(2017, 4, 7, 6, 24, 19), 'windspeed'),
#  (2.4864, datetime.datetime(2017, 4, 7, 6, 44, 20), 'windspeed'),
#  (2.331, datetime.datetime(2017, 4, 7, 7, 4, 21), 'windspeed'),
#  (2.7972, datetime.datetime(2017, 4, 7, 7, 24, 22), 'windspeed'),
#  (2.1756, datetime.datetime(2017, 4, 7, 7, 44, 23), 'windspeed'),
#  (3.108, datetime.datetime(2017, 4, 7, 8, 4, 24), 'windspeed'),
#  (2.6418, datetime.datetime(2017, 4, 7, 8, 24, 25), 'windspeed'),
#  (2.7195, datetime.datetime(2017, 4, 7, 8, 44, 26), 'windspeed'),
#  (2.0979, datetime.datetime(2017, 4, 7, 9, 4, 27), 'windspeed'),
#  (2.331, datetime.datetime(2017, 4, 7, 9, 24, 28), 'windspeed'),
#  (1.3209, datetime.datetime(2017, 4, 7, 9, 44, 29), 'windspeed'),
#  (2.0979, datetime.datetime(2017, 4, 7, 10, 4, 30), 'windspeed'),
#  (2.4087, datetime.datetime(2017, 4, 7, 10, 24, 31), 'windspeed'),
#  (2.7972, datetime.datetime(2017, 4, 7, 10, 44, 32), 'windspeed'),
#  (2.2533, datetime.datetime(2017, 4, 7, 11, 4, 33), 'windspeed'),
#  (2.2533, datetime.datetime(2017, 4, 7, 11, 24, 34), 'windspeed'),
#  (3.4965, datetime.datetime(2017, 4, 7, 11, 44, 35), 'windspeed'),
#  (0.8547, datetime.datetime(2017, 4, 7, 12, 4, 36), 'windspeed'),
#  (0.0777, datetime.datetime(2017, 4, 7, 12, 24, 37), 'windspeed'),
#  (0.4662, datetime.datetime(2017, 4, 7, 12, 44, 38), 'windspeed'),
#  (0.2331, datetime.datetime(2017, 4, 7, 13, 4, 39), 'windspeed'),
#  (0.3885, datetime.datetime(2017, 4, 7, 13, 24, 40), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 7, 13, 44, 41), 'windspeed'),
#  (1.4763, datetime.datetime(2017, 4, 7, 14, 4, 42), 'windspeed'),
#  (1.1655, datetime.datetime(2017, 4, 7, 14, 24, 43), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 7, 14, 44, 44), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 7, 15, 4, 45), 'windspeed'),
#  (0.5439, datetime.datetime(2017, 4, 7, 15, 24, 46), 'windspeed'),
#  (0.5439, datetime.datetime(2017, 4, 7, 15, 44, 47), 'windspeed'),
#  (0.5439, datetime.datetime(2017, 4, 7, 16, 4, 48), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 7, 16, 24, 49), 'windspeed'),
#  (0.1554, datetime.datetime(2017, 4, 7, 16, 44, 50), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 7, 17, 4, 51), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 7, 17, 24, 52), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 7, 17, 44, 53), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 7, 18, 4, 54), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 7, 18, 24, 55), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 7, 18, 44, 56), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 7, 19, 4, 57), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 7, 19, 24, 58), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 7, 19, 44, 59), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 7, 20, 5), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 7, 20, 25, 1), 'windspeed'),
#  (1.8648, datetime.datetime(2017, 4, 7, 20, 45, 2), 'windspeed'),
#  (1.7871, datetime.datetime(2017, 4, 7, 21, 5, 3), 'windspeed'),
#  (2.6418, datetime.datetime(2017, 4, 7, 21, 25, 4), 'windspeed'),
#  (2.6418, datetime.datetime(2017, 4, 7, 21, 45, 5), 'windspeed'),
#  (2.8749, datetime.datetime(2017, 4, 7, 22, 5, 6), 'windspeed'),
#  (1.8648, datetime.datetime(2017, 4, 7, 22, 25, 7), 'windspeed'),
#  (0.0777, datetime.datetime(2017, 4, 7, 22, 45, 8), 'windspeed'),
#  (0.6216, datetime.datetime(2017, 4, 7, 23, 5, 9), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 7, 23, 25, 10), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 7, 23, 45, 11), 'windspeed'),
#  (0.9324, datetime.datetime(2017, 4, 8, 0, 4), 'windspeed'),
#  (0.6993, datetime.datetime(2017, 4, 8, 0, 24, 1), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 0, 44, 2), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 1, 4, 3), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 1, 24, 4), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 1, 44, 5), 'windspeed'),
#  (0.9324, datetime.datetime(2017, 4, 8, 2, 4, 6), 'windspeed'),
#  (0.2331, datetime.datetime(2017, 4, 8, 2, 24, 7), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 2, 44, 8), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 3, 4, 9), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 3, 24, 10), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 3, 44, 11), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 4, 4, 12), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 4, 24, 13), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 4, 44, 14), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 5, 4, 15), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 5, 24, 16), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 5, 44, 17), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 6, 4, 18), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 6, 24, 19), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 6, 44, 20), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 7, 4, 21), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 7, 24, 22), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 7, 44, 23), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 8, 4, 24), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 8, 24, 25), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 8, 44, 26), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 9, 4, 27), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 9, 24, 28), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 9, 44, 29), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 10, 4, 30), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 10, 24, 31), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 10, 44, 32), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 11, 4, 33), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 11, 24, 34), 'windspeed'),
#  (0.3885, datetime.datetime(2017, 4, 8, 11, 44, 35), 'windspeed'),
#  (1.3986, datetime.datetime(2017, 4, 8, 12, 4, 36), 'windspeed'),
#  (0.8547, datetime.datetime(2017, 4, 8, 12, 24, 37), 'windspeed'),
#  (0.2331, datetime.datetime(2017, 4, 8, 12, 44, 38), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 13, 4, 39), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 13, 24, 40), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 13, 44, 41), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 14, 4, 42), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 14, 24, 43), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 14, 44, 44), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 15, 4, 45), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 15, 24, 46), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 15, 44, 47), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 16, 4, 48), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 16, 24, 49), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 16, 44, 50), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 17, 4, 51), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 17, 24, 52), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 17, 44, 53), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 18, 4, 54), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 18, 24, 55), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 18, 44, 56), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 19, 4, 57), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 19, 24, 58), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 19, 44, 59), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 20, 5), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 20, 25, 1), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 20, 45, 2), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 21, 5, 3), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 21, 25, 4), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 21, 45, 5), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 22, 5, 6), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 22, 25, 7), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 22, 45, 8), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 23, 5, 9), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 23, 25, 10), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 8, 23, 45, 11), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 9, 0, 4), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 9, 0, 24, 1), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 9, 0, 44, 2), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 9, 1, 4, 3), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 9, 1, 24, 4), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 9, 1, 44, 5), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 9, 2, 4, 6), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 9, 2, 24, 7), 'windspeed'),
#  (2.0202, datetime.datetime(2017, 4, 9, 2, 44, 8), 'windspeed'),
#  (2.4087, datetime.datetime(2017, 4, 9, 3, 4, 9), 'windspeed'),
#  (1.8648, datetime.datetime(2017, 4, 9, 3, 24, 10), 'windspeed'),
#  (2.0979, datetime.datetime(2017, 4, 9, 3, 44, 11), 'windspeed'),
#  (2.2533, datetime.datetime(2017, 4, 9, 4, 4, 12), 'windspeed'),
#  (1.6317, datetime.datetime(2017, 4, 9, 4, 24, 13), 'windspeed'),
#  (0.3885, datetime.datetime(2017, 4, 9, 4, 44, 14), 'windspeed'),
#  (0.3108, datetime.datetime(2017, 4, 9, 5, 4, 15), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 9, 5, 24, 16), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 9, 5, 44, 17), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 9, 6, 4, 18), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 9, 6, 24, 19), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 9, 6, 44, 20), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 9, 7, 4, 21), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 9, 7, 24, 22), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 9, 7, 44, 23), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 9, 8, 4, 24), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 9, 8, 24, 25), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 9, 8, 44, 26), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 9, 9, 4, 27), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 9, 9, 24, 28), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 9, 9, 44, 29), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 9, 10, 4, 30), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 9, 10, 24, 31), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 9, 10, 44, 32), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 9, 11, 4, 33), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 9, 11, 24, 34), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 9, 11, 44, 35), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 9, 12, 4, 36), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 9, 12, 24, 37), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 9, 12, 44, 38), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 9, 13, 4, 39), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 9, 13, 24, 40), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 9, 13, 44, 41), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 9, 14, 4, 42), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 9, 14, 24, 43), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 9, 14, 44, 44), 'windspeed'),
#  (1.0101, datetime.datetime(2017, 4, 9, 15, 4, 45), 'windspeed'),
#  (0.9324, datetime.datetime(2017, 4, 9, 15, 24, 46), 'windspeed'),
#  (0.6216, datetime.datetime(2017, 4, 9, 15, 44, 47), 'windspeed'),
#  (1.6317, datetime.datetime(2017, 4, 9, 16, 4, 48), 'windspeed'),
#  (2.331, datetime.datetime(2017, 4, 9, 16, 24, 49), 'windspeed'),
#  (2.4864, datetime.datetime(2017, 4, 9, 16, 44, 50), 'windspeed'),
#  (3.108, datetime.datetime(2017, 4, 9, 17, 4, 51), 'windspeed'),
#  (3.3411, datetime.datetime(2017, 4, 9, 17, 24, 52), 'windspeed'),
#  (3.6519, datetime.datetime(2017, 4, 9, 17, 44, 53), 'windspeed'),
#  (4.5843, datetime.datetime(2017, 4, 9, 18, 4, 54), 'windspeed'),
#  (4.4289, datetime.datetime(2017, 4, 9, 18, 24, 55), 'windspeed'),
#  (4.1958, datetime.datetime(2017, 4, 9, 18, 44, 56), 'windspeed'),
#  (3.9627, datetime.datetime(2017, 4, 9, 19, 4, 57), 'windspeed'),
#  (3.3411, datetime.datetime(2017, 4, 9, 19, 24, 58), 'windspeed'),
#  (2.7972, datetime.datetime(2017, 4, 9, 19, 44, 59), 'windspeed'),
#  (2.4864, datetime.datetime(2017, 4, 9, 20, 5), 'windspeed'),
#  (2.6418, datetime.datetime(2017, 4, 9, 20, 25, 1), 'windspeed'),
#  (2.4087, datetime.datetime(2017, 4, 9, 20, 45, 2), 'windspeed'),
#  (2.0979, datetime.datetime(2017, 4, 9, 21, 5, 3), 'windspeed'),
#  (2.0202, datetime.datetime(2017, 4, 9, 21, 25, 4), 'windspeed'),
#  (2.1756, datetime.datetime(2017, 4, 9, 21, 45, 5), 'windspeed'),
#  (1.7094, datetime.datetime(2017, 4, 9, 22, 5, 6), 'windspeed'),
#  (2.0202, datetime.datetime(2017, 4, 9, 22, 25, 7), 'windspeed'),
#  (2.1756, datetime.datetime(2017, 4, 9, 22, 45, 8), 'windspeed'),
#  (2.331, datetime.datetime(2017, 4, 9, 23, 5, 9), 'windspeed'),
#  (2.2533, datetime.datetime(2017, 4, 9, 23, 25, 10), 'windspeed'),
#  (2.4087, datetime.datetime(2017, 4, 9, 23, 45, 11), 'windspeed'),
#  (2.7972, datetime.datetime(2017, 4, 10, 0, 4), 'windspeed'),
#  (2.331, datetime.datetime(2017, 4, 10, 0, 24, 1), 'windspeed'),
#  (2.4864, datetime.datetime(2017, 4, 10, 0, 44, 2), 'windspeed'),
#  (3.6519, datetime.datetime(2017, 4, 10, 1, 4, 3), 'windspeed'),
#  (3.3411, datetime.datetime(2017, 4, 10, 1, 24, 4), 'windspeed'),
#  (4.5066, datetime.datetime(2017, 4, 10, 1, 44, 5), 'windspeed'),
#  (4.7397, datetime.datetime(2017, 4, 10, 2, 4, 6), 'windspeed'),
#  (4.5066, datetime.datetime(2017, 4, 10, 2, 24, 7), 'windspeed'),
#  (5.5944, datetime.datetime(2017, 4, 10, 2, 44, 8), 'windspeed'),
#  (5.5944, datetime.datetime(2017, 4, 10, 3, 4, 9), 'windspeed'),
#  (5.5944, datetime.datetime(2017, 4, 10, 3, 24, 10), 'windspeed'),
#  (5.5944, datetime.datetime(2017, 4, 10, 3, 44, 11), 'windspeed'),
#  (5.2836, datetime.datetime(2017, 4, 10, 4, 4, 12), 'windspeed'),
#  (5.1282, datetime.datetime(2017, 4, 10, 4, 24, 13), 'windspeed'),
#  (4.4289, datetime.datetime(2017, 4, 10, 4, 44, 14), 'windspeed'),
#  (5.3613, datetime.datetime(2017, 4, 10, 5, 4, 15), 'windspeed'),
#  (6.4491, datetime.datetime(2017, 4, 10, 5, 24, 16), 'windspeed'),
#  (6.6045, datetime.datetime(2017, 4, 10, 5, 44, 17), 'windspeed'),
#  (6.993, datetime.datetime(2017, 4, 10, 6, 4, 18), 'windspeed'),
#  (6.993, datetime.datetime(2017, 4, 10, 6, 24, 19), 'windspeed'),
#  (7.6146, datetime.datetime(2017, 4, 10, 6, 44, 20), 'windspeed'),
#  (6.9153, datetime.datetime(2017, 4, 10, 7, 4, 21), 'windspeed'),
#  (6.4491, datetime.datetime(2017, 4, 10, 7, 24, 22), 'windspeed'),
#  (4.9728, datetime.datetime(2017, 4, 10, 7, 44, 23), 'windspeed'),
#  (6.6045, datetime.datetime(2017, 4, 10, 8, 4, 24), 'windspeed'),
#  (4.2735, datetime.datetime(2017, 4, 10, 8, 24, 25), 'windspeed'),
#  (4.2735, datetime.datetime(2017, 4, 10, 8, 44, 26), 'windspeed'),
#  (5.2059, datetime.datetime(2017, 4, 10, 9, 4, 27), 'windspeed'),
#  (7.3038, datetime.datetime(2017, 4, 10, 9, 24, 28), 'windspeed'),
#  (6.6822, datetime.datetime(2017, 4, 10, 9, 44, 29), 'windspeed'),
#  (5.5167, datetime.datetime(2017, 4, 10, 10, 4, 30), 'windspeed'),
#  (5.5944, datetime.datetime(2017, 4, 10, 10, 24, 31), 'windspeed'),
#  (6.2937, datetime.datetime(2017, 4, 10, 10, 44, 32), 'windspeed'),
#  (8.7024, datetime.datetime(2017, 4, 10, 11, 4, 33), 'windspeed'),
#  (6.3714, datetime.datetime(2017, 4, 10, 11, 24, 34), 'windspeed'),
#  (6.5268, datetime.datetime(2017, 4, 10, 11, 44, 35), 'windspeed'),
#  (6.2937, datetime.datetime(2017, 4, 10, 12, 4, 36), 'windspeed'),
#  (9.2463, datetime.datetime(2017, 4, 10, 12, 24, 37), 'windspeed'),
#  (9.9456, datetime.datetime(2017, 4, 10, 12, 44, 38), 'windspeed'),
#  (9.7125, datetime.datetime(2017, 4, 10, 13, 4, 39), 'windspeed'),
#  (7.3815, datetime.datetime(2017, 4, 10, 13, 24, 40), 'windspeed'),
#  (5.8275, datetime.datetime(2017, 4, 10, 13, 44, 41), 'windspeed'),
#  (5.1282, datetime.datetime(2017, 4, 10, 14, 4, 42), 'windspeed'),
#  (8.3916, datetime.datetime(2017, 4, 10, 14, 24, 43), 'windspeed'),
#  (8.1585, datetime.datetime(2017, 4, 10, 14, 44, 44), 'windspeed'),
#  (5.439, datetime.datetime(2017, 4, 10, 15, 4, 45), 'windspeed'),
#  (5.5944, datetime.datetime(2017, 4, 10, 15, 24, 46), 'windspeed'),
#  (5.2836, datetime.datetime(2017, 4, 10, 15, 44, 47), 'windspeed'),
#  (3.5742, datetime.datetime(2017, 4, 10, 16, 4, 48), 'windspeed'),
#  (3.885, datetime.datetime(2017, 4, 10, 16, 24, 49), 'windspeed'),
#  (2.7972, datetime.datetime(2017, 4, 10, 16, 44, 50), 'windspeed'),
#  (5.9052, datetime.datetime(2017, 4, 10, 17, 4, 51), 'windspeed'),
#  (6.4491, datetime.datetime(2017, 4, 10, 17, 24, 52), 'windspeed'),
#  (4.662, datetime.datetime(2017, 4, 10, 17, 44, 53), 'windspeed'),
#  (7.4592, datetime.datetime(2017, 4, 10, 18, 4, 54), 'windspeed'),
#  (8.3916, datetime.datetime(2017, 4, 10, 18, 24, 55), 'windspeed'),
#  (8.3139, datetime.datetime(2017, 4, 10, 18, 44, 56), 'windspeed'),
#  (7.0707, datetime.datetime(2017, 4, 10, 19, 4, 57), 'windspeed'),
#  (5.6721, datetime.datetime(2017, 4, 10, 19, 24, 58), 'windspeed'),
#  (5.1282, datetime.datetime(2017, 4, 10, 19, 44, 59), 'windspeed'),
#  (6.5268, datetime.datetime(2017, 4, 10, 20, 5), 'windspeed'),
#  (5.8275, datetime.datetime(2017, 4, 10, 20, 25, 1), 'windspeed'),
#  (6.216, datetime.datetime(2017, 4, 10, 20, 45, 2), 'windspeed'),
#  (5.9829, datetime.datetime(2017, 4, 10, 21, 5, 3), 'windspeed'),
#  (5.6721, datetime.datetime(2017, 4, 10, 21, 25, 4), 'windspeed'),
#  (5.1282, datetime.datetime(2017, 4, 10, 21, 45, 5), 'windspeed'),
#  (5.9052, datetime.datetime(2017, 4, 10, 22, 5, 6), 'windspeed'),
#  (8.4693, datetime.datetime(2017, 4, 10, 22, 25, 7), 'windspeed'),
#  (8.9355, datetime.datetime(2017, 4, 10, 22, 45, 8), 'windspeed'),
#  (9.0132, datetime.datetime(2017, 4, 10, 23, 5, 9), 'windspeed'),
#  (10.0233, datetime.datetime(2017, 4, 10, 23, 25, 10), 'windspeed'),
#  (10.4895, datetime.datetime(2017, 4, 10, 23, 45, 11), 'windspeed'),
#  (11.0334, datetime.datetime(2017, 4, 11, 0, 4), 'windspeed'),
#  (9.4017, datetime.datetime(2017, 4, 11, 0, 24, 1), 'windspeed'),
#  (9.324, datetime.datetime(2017, 4, 11, 0, 44, 2), 'windspeed'),
#  (8.7024, datetime.datetime(2017, 4, 11, 1, 4, 3), 'windspeed'),
#  (9.1686, datetime.datetime(2017, 4, 11, 1, 24, 4), 'windspeed'),
#  (8.0031, datetime.datetime(2017, 4, 11, 1, 44, 5), 'windspeed'),
#  (6.5268, datetime.datetime(2017, 4, 11, 2, 4, 6), 'windspeed'),
#  (5.7498, datetime.datetime(2017, 4, 11, 2, 24, 7), 'windspeed'),
#  (7.3815, datetime.datetime(2017, 4, 11, 2, 44, 8), 'windspeed'),
#  (9.324, datetime.datetime(2017, 4, 11, 3, 4, 9), 'windspeed'),
#  (9.5571, datetime.datetime(2017, 4, 11, 3, 24, 10), 'windspeed'),
#  (9.7125, datetime.datetime(2017, 4, 11, 3, 44, 11), 'windspeed'),
#  (9.1686, datetime.datetime(2017, 4, 11, 4, 4, 12), 'windspeed'),
#  (8.6247, datetime.datetime(2017, 4, 11, 4, 24, 13), 'windspeed'),
#  (6.8376, datetime.datetime(2017, 4, 11, 4, 44, 14), 'windspeed'),
#  (2.8749, datetime.datetime(2017, 4, 11, 5, 4, 15), 'windspeed'),
#  (1.6317, datetime.datetime(2017, 4, 11, 5, 24, 16), 'windspeed'),
# ...
#  (2.9526, datetime.datetime(2017, 4, 11, 13, 4, 39), 'windspeed'),
#  (3.2634, datetime.datetime(2017, 4, 11, 13, 24, 40), 'windspeed'),
#  (2.6418, datetime.datetime(2017, 4, 11, 13, 44, 41), 'windspeed'),
#  (1.9425, datetime.datetime(2017, 4, 11, 14, 4, 42), 'windspeed'),
#  (1.3209, datetime.datetime(2017, 4, 11, 14, 24, 43), 'windspeed'),
#  (1.1655, datetime.datetime(2017, 4, 11, 14, 44, 44), 'windspeed'),
#  (1.4763, datetime.datetime(2017, 4, 11, 15, 4, 45), 'windspeed'),
#  (1.7094, datetime.datetime(2017, 4, 11, 15, 24, 46), 'windspeed'),
#  (1.0878, datetime.datetime(2017, 4, 11, 15, 44, 47), 'windspeed'),
#  (1.8648, datetime.datetime(2017, 4, 11, 16, 4, 48), 'windspeed'),
#  (1.7094, datetime.datetime(2017, 4, 11, 16, 24, 49), 'windspeed'),
#  (1.7094, datetime.datetime(2017, 4, 11, 16, 44, 50), 'windspeed'),
#  (0.9324, datetime.datetime(2017, 4, 11, 17, 4, 51), 'windspeed'),
#  (0.4662, datetime.datetime(2017, 4, 11, 17, 24, 52), 'windspeed'),
#  (0.1554, datetime.datetime(2017, 4, 11, 17, 44, 53), 'windspeed'),
#  (0.4662, datetime.datetime(2017, 4, 11, 18, 4, 54), 'windspeed'),
#  (0.2331, datetime.datetime(2017, 4, 11, 18, 24, 55), 'windspeed'),
#  (0.2331, datetime.datetime(2017, 4, 11, 18, 44, 56), 'windspeed'),
#  (0.6993, datetime.datetime(2017, 4, 11, 19, 4, 57), 'windspeed'),
#  (0.6993, datetime.datetime(2017, 4, 11, 19, 24, 58), 'windspeed'),
#  (0.9324, datetime.datetime(2017, 4, 11, 19, 44, 59), 'windspeed'),
#  (0.5439, datetime.datetime(2017, 4, 11, 20, 5), 'windspeed'),
#  (1.0878, datetime.datetime(2017, 4, 11, 20, 25, 1), 'windspeed'),
#  (1.1655, datetime.datetime(2017, 4, 11, 20, 45, 2), 'windspeed'),
#  (1.4763, datetime.datetime(2017, 4, 11, 21, 5, 3), 'windspeed'),
#  (0.9324, datetime.datetime(2017, 4, 11, 21, 25, 4), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 11, 21, 45, 5), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 11, 22, 5, 6), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 11, 22, 25, 7), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 11, 22, 45, 8), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 11, 23, 5, 9), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 11, 23, 25, 10), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 11, 23, 45, 11), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 12, 0, 4), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 12, 0, 24, 1), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 12, 0, 44, 2), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 12, 1, 4, 3), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 12, 1, 24, 4), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 12, 1, 44, 5), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 12, 2, 4, 6), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 12, 2, 24, 7), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 12, 2, 44, 8), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 12, 3, 4, 9), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 12, 3, 24, 10), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 12, 3, 44, 11), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 12, 4, 4, 12), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 12, 4, 24, 13), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 12, 4, 44, 14), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 12, 5, 4, 15), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 12, 5, 24, 16), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 12, 5, 44, 17), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 12, 6, 4, 18), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 12, 6, 24, 19), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 12, 6, 44, 20), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 12, 7, 4, 21), 'windspeed'),
#  (0.0777, datetime.datetime(2017, 4, 12, 7, 24, 22), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 12, 7, 44, 23), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 12, 8, 4, 24), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 12, 8, 24, 25), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 12, 8, 44, 26), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 12, 9, 4, 27), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 12, 9, 24, 28), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 12, 9, 44, 29), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 12, 10, 4, 30), 'windspeed'),
#  (0.0777, datetime.datetime(2017, 4, 12, 10, 24, 31), 'windspeed'),
#  (0.3885, datetime.datetime(2017, 4, 12, 10, 44, 32), 'windspeed'),
#  (0.3108, datetime.datetime(2017, 4, 12, 11, 4, 33), 'windspeed'),
#  (0.2331, datetime.datetime(2017, 4, 12, 11, 24, 34), 'windspeed'),
#  (0.6216, datetime.datetime(2017, 4, 12, 11, 44, 35), 'windspeed'),
#  (1.0101, datetime.datetime(2017, 4, 12, 12, 4, 36), 'windspeed'),
#  (1.4763, datetime.datetime(2017, 4, 12, 12, 24, 37), 'windspeed'),
#  (1.7094, datetime.datetime(2017, 4, 12, 12, 44, 38), 'windspeed'),
#  (1.7094, datetime.datetime(2017, 4, 12, 13, 4, 39), 'windspeed'),
#  (1.7871, datetime.datetime(2017, 4, 12, 13, 24, 40), 'windspeed'),
#  (1.6317, datetime.datetime(2017, 4, 12, 13, 44, 41), 'windspeed'),
#  (2.331, datetime.datetime(2017, 4, 12, 14, 4, 42), 'windspeed'),
#  (3.1857, datetime.datetime(2017, 4, 12, 14, 24, 43), 'windspeed'),
#  (3.7296, datetime.datetime(2017, 4, 12, 14, 44, 44), 'windspeed'),
#  (4.1181, datetime.datetime(2017, 4, 12, 15, 4, 45), 'windspeed'),
#  (4.5843, datetime.datetime(2017, 4, 12, 15, 24, 46), 'windspeed'),
#  (4.3512, datetime.datetime(2017, 4, 12, 15, 44, 47), 'windspeed'),
#  (4.5066, datetime.datetime(2017, 4, 12, 16, 4, 48), 'windspeed'),
#  (3.885, datetime.datetime(2017, 4, 12, 16, 24, 49), 'windspeed'),
#  (5.1282, datetime.datetime(2017, 4, 12, 16, 44, 50), 'windspeed'),
#  (5.2059, datetime.datetime(2017, 4, 12, 17, 4, 51), 'windspeed'),
#  (5.9829, datetime.datetime(2017, 4, 12, 17, 24, 52), 'windspeed'),
#  (5.3613, datetime.datetime(2017, 4, 12, 17, 44, 53), 'windspeed'),
#  (4.3512, datetime.datetime(2017, 4, 12, 18, 4, 54), 'windspeed'),
#  (3.108, datetime.datetime(2017, 4, 12, 18, 24, 55), 'windspeed'),
#  (3.5742, datetime.datetime(2017, 4, 12, 18, 44, 56), 'windspeed'),
#  (4.7397, datetime.datetime(2017, 4, 12, 19, 4, 57), 'windspeed'),
#  (4.8951, datetime.datetime(2017, 4, 12, 19, 24, 58), 'windspeed'),
#  (3.3411, datetime.datetime(2017, 4, 12, 19, 44, 59), 'windspeed'),
#  (3.8073, datetime.datetime(2017, 4, 12, 20, 5), 'windspeed'),
#  (2.9526, datetime.datetime(2017, 4, 12, 20, 25, 1), 'windspeed'),
#  (4.1958, datetime.datetime(2017, 4, 12, 20, 45, 2), 'windspeed'),
#  (3.4188, datetime.datetime(2017, 4, 12, 21, 5, 3), 'windspeed'),
#  (5.2059, datetime.datetime(2017, 4, 12, 21, 25, 4), 'windspeed'),
#  (4.5066, datetime.datetime(2017, 4, 12, 21, 45, 5), 'windspeed'),
#  (5.7498, datetime.datetime(2017, 4, 12, 22, 5, 6), 'windspeed'),
#  (6.6822, datetime.datetime(2017, 4, 12, 22, 25, 7), 'windspeed'),
#  (8.3139, datetime.datetime(2017, 4, 12, 22, 45, 8), 'windspeed'),
#  (8.6247, datetime.datetime(2017, 4, 12, 23, 5, 9), 'windspeed'),
#  (8.3139, datetime.datetime(2017, 4, 12, 23, 25, 10), 'windspeed'),
#  (7.3815, datetime.datetime(2017, 4, 12, 23, 45, 11), 'windspeed'),
#  (6.3714, datetime.datetime(2017, 4, 13, 0, 4), 'windspeed'),
#  (8.1585, datetime.datetime(2017, 4, 13, 0, 24, 1), 'windspeed'),
#  (9.1686, datetime.datetime(2017, 4, 13, 0, 44, 2), 'windspeed'),
#  (10.2564, datetime.datetime(2017, 4, 13, 1, 4, 3), 'windspeed'),
#  (10.6449, datetime.datetime(2017, 4, 13, 1, 24, 4), 'windspeed'),
#  (10.9557, datetime.datetime(2017, 4, 13, 1, 44, 5), 'windspeed'),
#  (9.7902, datetime.datetime(2017, 4, 13, 2, 4, 6), 'windspeed'),
#  (10.3341, datetime.datetime(2017, 4, 13, 2, 24, 7), 'windspeed'),
#  (10.8003, datetime.datetime(2017, 4, 13, 2, 44, 8), 'windspeed'),
#  (10.8003, datetime.datetime(2017, 4, 13, 3, 4, 9), 'windspeed'),
#  (10.9557, datetime.datetime(2017, 4, 13, 3, 24, 10), 'windspeed'),
#  (9.5571, datetime.datetime(2017, 4, 13, 3, 44, 11), 'windspeed'),
#  (9.7125, datetime.datetime(2017, 4, 13, 4, 4, 12), 'windspeed'),
#  (9.6348, datetime.datetime(2017, 4, 13, 4, 24, 13), 'windspeed'),
#  (8.9355, datetime.datetime(2017, 4, 13, 4, 44, 14), 'windspeed'),
#  (9.0909, datetime.datetime(2017, 4, 13, 5, 4, 15), 'windspeed'),
#  (8.7024, datetime.datetime(2017, 4, 13, 5, 24, 16), 'windspeed'),
#  (9.4017, datetime.datetime(2017, 4, 13, 5, 44, 17), 'windspeed'),
#  (8.7024, datetime.datetime(2017, 4, 13, 6, 4, 18), 'windspeed'),
#  (8.547, datetime.datetime(2017, 4, 13, 6, 24, 19), 'windspeed'),
#  (8.3916, datetime.datetime(2017, 4, 13, 6, 44, 20), 'windspeed'),
#  (7.3038, datetime.datetime(2017, 4, 13, 7, 4, 21), 'windspeed'),
#  (8.7024, datetime.datetime(2017, 4, 13, 7, 24, 22), 'windspeed'),
#  (9.2463, datetime.datetime(2017, 4, 13, 7, 44, 23), 'windspeed'),
#  (10.7226, datetime.datetime(2017, 4, 13, 8, 4, 24), 'windspeed'),
#  (11.1888, datetime.datetime(2017, 4, 13, 8, 24, 25), 'windspeed'),
#  (11.2665, datetime.datetime(2017, 4, 13, 8, 44, 26), 'windspeed'),
#  (10.1787, datetime.datetime(2017, 4, 13, 9, 4, 27), 'windspeed'),
#  (11.4996, datetime.datetime(2017, 4, 13, 9, 24, 28), 'windspeed'),
#  (11.3442, datetime.datetime(2017, 4, 13, 9, 44, 29), 'windspeed'),
#  (9.7902, datetime.datetime(2017, 4, 13, 10, 4, 30), 'windspeed'),
#  (10.8003, datetime.datetime(2017, 4, 13, 10, 24, 31), 'windspeed'),
#  (11.2665, datetime.datetime(2017, 4, 13, 10, 44, 32), 'windspeed'),
#  (10.2564, datetime.datetime(2017, 4, 13, 11, 4, 33), 'windspeed'),
#  (9.7902, datetime.datetime(2017, 4, 13, 11, 24, 34), 'windspeed'),
#  (10.4118, datetime.datetime(2017, 4, 13, 11, 44, 35), 'windspeed'),
#  (10.1787, datetime.datetime(2017, 4, 13, 12, 4, 36), 'windspeed'),
#  (10.3341, datetime.datetime(2017, 4, 13, 12, 24, 37), 'windspeed'),
#  (12.5097, datetime.datetime(2017, 4, 13, 12, 44, 38), 'windspeed'),
#  (10.878, datetime.datetime(2017, 4, 13, 13, 4, 39), 'windspeed'),
#  (10.2564, datetime.datetime(2017, 4, 13, 13, 24, 40), 'windspeed'),
#  (11.4996, datetime.datetime(2017, 4, 13, 13, 44, 41), 'windspeed'),
#  (11.2665, datetime.datetime(2017, 4, 13, 14, 4, 42), 'windspeed'),
#  (9.9456, datetime.datetime(2017, 4, 13, 14, 24, 43), 'windspeed'),
#  (8.8578, datetime.datetime(2017, 4, 13, 14, 44, 44), 'windspeed'),
#  (7.3038, datetime.datetime(2017, 4, 13, 15, 4, 45), 'windspeed'),
#  (7.3038, datetime.datetime(2017, 4, 13, 15, 24, 46), 'windspeed'),
#  (6.5268, datetime.datetime(2017, 4, 13, 15, 44, 47), 'windspeed'),
#  (5.7498, datetime.datetime(2017, 4, 13, 16, 4, 48), 'windspeed'),
#  (7.1484, datetime.datetime(2017, 4, 13, 16, 24, 49), 'windspeed'),
#  (6.8376, datetime.datetime(2017, 4, 13, 16, 44, 50), 'windspeed'),
#  (6.9153, datetime.datetime(2017, 4, 13, 17, 4, 51), 'windspeed'),
#  (9.0132, datetime.datetime(2017, 4, 13, 17, 24, 52), 'windspeed'),
#  (7.3038, datetime.datetime(2017, 4, 13, 17, 44, 53), 'windspeed'),
#  (7.2261, datetime.datetime(2017, 4, 13, 18, 4, 54), 'windspeed'),
#  (5.6721, datetime.datetime(2017, 4, 13, 18, 24, 55), 'windspeed'),
#  (3.2634, datetime.datetime(2017, 4, 13, 18, 44, 56), 'windspeed'),
#  (5.9829, datetime.datetime(2017, 4, 13, 19, 4, 57), 'windspeed'),
#  (5.9829, datetime.datetime(2017, 4, 13, 19, 24, 58), 'windspeed'),
#  (2.6418, datetime.datetime(2017, 4, 13, 19, 44, 59), 'windspeed'),
#  (1.2432, datetime.datetime(2017, 4, 13, 20, 5), 'windspeed'),
#  (0.3108, datetime.datetime(2017, 4, 13, 20, 25, 1), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 13, 20, 45, 2), 'windspeed'),
#  (1.7871, datetime.datetime(2017, 4, 13, 21, 5, 3), 'windspeed'),
#  (4.1958, datetime.datetime(2017, 4, 13, 21, 25, 4), 'windspeed'),
#  (5.0505, datetime.datetime(2017, 4, 13, 21, 45, 5), 'windspeed'),
#  (4.8174, datetime.datetime(2017, 4, 13, 22, 5, 6), 'windspeed'),
#  (5.5167, datetime.datetime(2017, 4, 13, 22, 25, 7), 'windspeed'),
#  (5.0505, datetime.datetime(2017, 4, 13, 22, 45, 8), 'windspeed'),
#  (4.7397, datetime.datetime(2017, 4, 13, 23, 5, 9), 'windspeed'),
#  (4.8174, datetime.datetime(2017, 4, 13, 23, 25, 10), 'windspeed'),
#  (0.9324, datetime.datetime(2017, 4, 13, 23, 45, 11), 'windspeed'),
#  (0.4662, datetime.datetime(2017, 4, 14, 0, 4), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 14, 0, 24, 1), 'windspeed'),
#  (0.0777, datetime.datetime(2017, 4, 14, 0, 44, 2), 'windspeed'),
#  (0.0777, datetime.datetime(2017, 4, 14, 1, 4, 3), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 14, 1, 24, 4), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 14, 1, 44, 5), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 14, 2, 4, 6), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 14, 2, 24, 7), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 14, 2, 44, 8), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 14, 3, 4, 9), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 14, 3, 24, 10), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 14, 3, 44, 11), 'windspeed'),
#  (0.1554, datetime.datetime(2017, 4, 14, 4, 4, 12), 'windspeed'),
#  (1.1655, datetime.datetime(2017, 4, 14, 4, 24, 13), 'windspeed'),
#  (1.9425, datetime.datetime(2017, 4, 14, 4, 44, 14), 'windspeed'),
#  (1.4763, datetime.datetime(2017, 4, 14, 5, 4, 15), 'windspeed'),
#  (2.1756, datetime.datetime(2017, 4, 14, 5, 24, 16), 'windspeed'),
#  (2.331, datetime.datetime(2017, 4, 14, 5, 44, 17), 'windspeed'),
#  (2.0979, datetime.datetime(2017, 4, 14, 6, 4, 18), 'windspeed'),
#  (1.0878, datetime.datetime(2017, 4, 14, 6, 24, 19), 'windspeed'),
#  (0.1554, datetime.datetime(2017, 4, 14, 6, 44, 20), 'windspeed'),
#  (0.0777, datetime.datetime(2017, 4, 14, 7, 4, 21), 'windspeed'),
#  (0.1554, datetime.datetime(2017, 4, 14, 7, 24, 22), 'windspeed'),
#  (0.6216, datetime.datetime(2017, 4, 14, 7, 44, 23), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 14, 8, 4, 24), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 14, 8, 24, 25), 'windspeed'),
#  (0.2331, datetime.datetime(2017, 4, 14, 8, 44, 26), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 14, 9, 4, 27), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 14, 9, 24, 28), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 14, 9, 44, 29), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 14, 10, 4, 30), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 14, 10, 24, 31), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 14, 10, 44, 32), 'windspeed'),
#  (0.2331, datetime.datetime(2017, 4, 14, 11, 4, 33), 'windspeed'),
#  (0.4662, datetime.datetime(2017, 4, 14, 11, 24, 34), 'windspeed'),
#  (0.2331, datetime.datetime(2017, 4, 14, 11, 44, 35), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 14, 12, 4, 36), 'windspeed'),
#  (0.0, datetime.datetime(2017, 4, 14, 12, 24, 37), 'windspeed'),
#  (0.0777, datetime.datetime(2017, 4, 14, 12, 44, 38), 'windspeed'),
#  (0.1554, datetime.datetime(2017, 4, 14, 13, 4, 39), 'windspeed'),
#  (0.5439, datetime.datetime(2017, 4, 14, 13, 24, 40), 'windspeed'),
#  (0.4662, datetime.datetime(2017, 4, 14, 13, 44, 41), 'windspeed'),
#  (0.777, datetime.datetime(2017, 4, 14, 14, 4, 42), 'windspeed'),
#  (2.4864, datetime.datetime(2017, 4, 14, 14, 24, 43), 'windspeed'),
#  (2.9526, datetime.datetime(2017, 4, 14, 14, 44, 44), 'windspeed'),
#  (3.0303, datetime.datetime(2017, 4, 14, 15, 4, 45), 'windspeed'),
#  (2.5641, datetime.datetime(2017, 4, 14, 15, 24, 46), 'windspeed'),
#  (2.9526, datetime.datetime(2017, 4, 14, 15, 44, 47), 'windspeed'),
#  (4.7397, datetime.datetime(2017, 4, 14, 16, 4, 48), 'windspeed'),
#  (4.4289, datetime.datetime(2017, 4, 14, 16, 24, 49), 'windspeed'),
#  (5.5167, datetime.datetime(2017, 4, 14, 16, 44, 50), 'windspeed'),
#  (5.8275, datetime.datetime(2017, 4, 14, 17, 4, 51), 'windspeed'),
#  (5.3613, datetime.datetime(2017, 4, 14, 17, 24, 52), 'windspeed'),
#  (5.1282, datetime.datetime(2017, 4, 14, 17, 44, 53), 'windspeed'),
#  (5.2836, datetime.datetime(2017, 4, 14, 18, 4, 54), 'windspeed'),
#  (5.2836, datetime.datetime(2017, 4, 14, 18, 24, 55), 'windspeed'),
#  (6.8376, datetime.datetime(2017, 4, 14, 18, 44, 56), 'windspeed'),
#  (6.216, datetime.datetime(2017, 4, 14, 19, 4, 57), 'windspeed'),
#  (4.4289, datetime.datetime(2017, 4, 14, 19, 24, 58), 'windspeed'),
#  (3.3411, datetime.datetime(2017, 4, 14, 19, 44, 59), 'windspeed'),
#  (3.4965, datetime.datetime(2017, 4, 14, 20, 5), 'windspeed'),
#  (4.9728, datetime.datetime(2017, 4, 14, 20, 25, 1), 'windspeed'),
#  (7.3815, datetime.datetime(2017, 4, 14, 20, 45, 2), 'windspeed'),
#  (7.6146, datetime.datetime(2017, 4, 14, 21, 5, 3), 'windspeed'),
#  ...]

# %% [markdown]
# ## Parse the data
#
# The data obtained are in the form of a list of tuples:

# %%
logging.debug(type(data))
logging.debug(data[-1])
# Out:
# DEBUG:root:<class 'list'>
# DEBUG:root:(2.5641, datetime.datetime(2017, 5, 31, 23, 40, 26), 'windspeed')

# %% [markdown]
# We convert the list of tuples to two separate lists:
# * one for the wind speed mesurements,
# * the other for the datatime objects.

# %%
windspeed, datetimelist = [], []
for dd in data:
    windspeed.append(dd[0])
    datetimelist.append(dd[1])

# %% [markdown]
# # Make a plot
#
# The `plot` function accepts the datetime as an argument.

# %%
fig = plt.figure(figsize=(12, 10))
plt.plot(datetimelist, windspeed)
plt.xlabel("Time")
plt.ylabel("Wind speed\n(m/s)", rotation=0, ha='right')
fig.autofmt_xdate()
plt.show()
plt.close()

# %%
import numpy as np
import pandas as pd
import pandas_highcharts
from pandas_highcharts.display import display_charts
# Out:
# <script src="//code.highcharts.com/stock/highstock.js"></script>
# <script src="//code.highcharts.com/highcharts-more.js"></script>
# <script src="//code.highcharts.com/modules/exporting.js"></script>

# %% [markdown]
# Create a pandas data frame to use with highcharts.
# We have to set the index properly for further visualisation.

# %%
windspeedDF = pd.DataFrame(
    {'datetime': np.array(datetimelist),
     'windspeed': windspeed
    })
windspeedDF = windspeedDF.set_index('datetime')

# %%
display_charts(windspeedDF, chart_type="stock", title="Wind speed")
# Out:
# <div id="chart_idZroBfWjr"</div>
#     <script type="text/javascript">new Highcharts.StockChart({"chart":{"renderTo":"chart_idZroBfWjr"},"legend":{"enabled":true},"series":[{"name":"windspeed","yAxis":0,"data":[[1491005040000,0.1554],[1491006241000,0.3885],[1491007442000,0.0],[1491008643000,0.0],[1491009844000,0.0],[1491011045000,0.0],[1491012246000,0.0],[1491013447000,0.0],[1491014648000,0.3885],[1491015849000,3.1857],[1491017050000,3.4188],[1491018251000,3.7296],[1491019452000,3.108],[1491020653000,2.2533],[1491021854000,0.8547],[1491023055000,0.777],[1491024256000,1.0878],[1491025457000,1.554],[1491026658000,0.0],[1491027859000,0.0777],[1491029060000,1.3209],[1491030261000,2.6418],[1491031462000,2.6418],[1491032663000,2.1756],[1491033864000,0.2331],[1491035065000,0.0],[1491036266000,1.0101],[1491037467000,1.9425],[1491038668000,1.9425],[1491039869000,1.9425],[1491041070000,2.331],[1491042271000,2.331],[1491043472000,1.3986],[1491044673000,0.6216],[1491045874000,0.0777],[1491047075000,1.3209],[1491048276000,0.5439],[1491049477000,0.9324],[1491050678000,0.9324],[1491051879000,1.7094],[1491053080000,1.7094],[1491054281000,2.0202],[1491055482000,2.0202],[1491056683000,2.5641],[1491057884000,1.9425],[1491059085000,2.1756],[1491060286000,2.4087],[1491061487000,2.4087],[1491062688000,3.0303],[1491063889000,2.5641],[1491065090000,2.9526],[1491066291000,2.0202],[1491067492000,3.2634],[1491068693000,4.5843],[1491069894000,3.9627],[1491071095000,2.0202],[1491072296000,2.331],[1491073497000,4.9728],[1491074698000,5.2059],[1491075899000,6.216],[1491077100000,8.7024],[1491078301000,9.6348],[1491079502000,5.6721],[1491080703000,0.6216],[1491081904000,5.3613],[1491083105000,6.7599],[1491084306000,5.5167],[1491085507000,5.8275],[1491086708000,5.439],[1491087909000,4.8951],[1491089110000,3.9627],[1491090311000,3.5742],[1491091440000,6.0606],[1491092641000,8.3916],[1491093842000,6.6822],[1491095043000,6.1383],[1491096244000,6.1383],[1491097445000,4.7397],[1491098646000,2.1756],[1491099847000,0.1554],[1491101048000,0.0],[1491102249000,0.0777],[1491103450000,0.3108],[1491104651000,0.8547],[1491105852000,2.1756],[1491107053000,2.0979],[1491108254000,3.4188],[1491109455000,3.7296],[1491110656000,4.3512],[1491111857000,4.7397],[1491113058000,5.1282],[1491114259000,3.7296],[1491115460000,3.7296],[1491116661000,2.2533],[1491117862000,2.0979],[1491119063000,1.9425],[1491120264000,0.9324],[1491121465000,0.0777],[1491122666000,2.0979],[1491123867000,3.2634],[1491125068000,2.8749],[1491126269000,2.7972],[1491127470000,2.8749],[1491128671000,2.9526],[1491129872000,2.331],[1491131073000,2.0202],[1491132274000,1.7094],[1491133475000,1.3209],[1491134676000,2.2533],[1491135877000,4.3512],[1491137078000,4.8174],[1491138279000,5.7498],[1491139480000,6.0606],[1491140681000,5.5167],[1491141882000,4.1181],[1491143083000,2.8749],[1491144284000,3.108],[1491145485000,3.2634],[1491146686000,5.2836],[1491147887000,8.547],[1491149088000,9.8679],[1491150289000,8.3916],[1491151490000,8.0031],[1491152691000,8.0808],[1491153892000,7.8477],[1491155093000,8.6247],[1491156294000,9.4017],[1491157495000,7.8477],[1491158696000,6.3714],[1491159897000,7.0707],[1491161098000,9.7902],[1491162299000,10.4118],[1491163500000,9.324],[1491164701000,8.4693],[1491165902000,8.2362],[1491167103000,7.5369],[1491168304000,8.0031],[1491169505000,9.5571],[1491170706000,10.6449],[1491171907000,10.4118],[1491173108000,9.7902],[1491174309000,9.9456],[1491175510000,10.1787],[1491176711000,9.8679],[1491177840000,9.4017],[1491179041000,8.6247],[1491180242000,8.0808],[1491181443000,8.0808],[1491182644000,6.6822],[1491183845000,7.6923],[1491185046000,8.7024],[1491186247000,7.0707],[1491187448000,6.6045],[1491188649000,6.993],[1491189850000,6.2937],[1491191051000,4.9728],[1491192252000,6.4491],[1491193453000,6.9153],[1491194654000,7.0707],[1491195855000,6.993],[1491197056000,7.3038],[1491198257000,7.5369],[1491199458000,7.6146],[1491200659000,7.6146],[1491201860000,7.8477],[1491203061000,8.2362],[1491204262000,8.9355],[1491205463000,9.090 ...
